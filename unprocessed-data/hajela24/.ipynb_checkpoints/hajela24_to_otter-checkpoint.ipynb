# %% [markdown]
# # Reformat the data from Ridley+2023 on AT2017bcc into the OTTER JSON format
#
# ### Metadata First

# %%
import os
import pandas as pd
import numpy as np
import otter

from astropy import units as u

from dataclasses import dataclass

@dataclass
class Args:
    otterdir: str
    indir: str
    
@dataclass
class Param:
    name: float | str | int
    unit: str
    description: str = None

    
args = Args(
    otterdir=".otter",
    indir=os.getcwd()
)

month_map = dict(
    Jan = "01",
    Feb = "02",
    Mar = "03",
    Apr = "04",
    May = "05",
    Jun = "06",
    Jul = "07",
    Aug = "08",
    Sep = "09",
    Oct = "10",
    Nov = "11",
    Dec = "12"
)

# %%
hajela24_bibcode = "2024arXiv240719019H"

meta = dict(
    name = dict(
        default_name = "ASASSN-15oi",
        alias = [dict(value="ASASSN-15oi", reference=[hajela24_bibcode])]
    ),

    coordinate = [dict(
        reference = ["2016MNRAS.463.3813H"],
        ra = "20:39:09.12",
        dec = "-30:45:20.84",
        ra_units = "hourangle",
        dec_units = "deg",
        default = True,
        coordinate_type = "equitorial"
    )],
    
    reference_alias = [
        dict(name=hajela24_bibcode, human_readable_name="Hajela et al. (2024)"),
        dict(name="2016MNRAS.463.3813H", human_readable_name="Holoien et al. (2016)"),
        dict(name="2020PASP..132c5001L", human_readable_name="Lucy et al. (2020)")
    ]
)

meta
# Out:
# {'name': {'default_name': 'ASASSN-15oi',
#   'alias': [{'value': 'ASASSN-15oi', 'reference': ['2024arXiv240719019H']}]},
#  'coordinate': [{'reference': ['2016MNRAS.463.3813H'],
#    'ra': '20:39:09.12',
#    'dec': '-30:45:20.84',
#    'ra_units': 'hourangle',
#    'dec_units': 'deg',
#    'default': True,
#    'coordinate_type': 'equitorial'}],
#  'reference_alias': [{'name': '2024arXiv240719019H',
#    'human_readable_name': 'Hajela et al. (2024)'},
#   {'name': '2016MNRAS.463.3813H',
#    'human_readable_name': 'Holoien et al. (2016)'},
#   {'name': '2020PASP..132c5001L',
#    'human_readable_name': 'Lucy et al. (2020)'}]}

# %% [markdown]
# ### UVOIR Dataset

# %%
uvoir = pd.read_csv(os.path.join(args.indir, "asassn15oi_uvoir.txt"), sep=" ", index_col=False)

uvoir_phot = dict(
    reference = [hajela24_bibcode],
    raw = uvoir.Magnitude.tolist(),
    raw_err = uvoir.Magnitude_Error.tolist(),
    raw_units = "mag(AB)",
    corr_k = False,
    corr_s = False,
    corr_av = True,
    corr_host = False,
    corr_hostav = False,
    val_av = 0.185,
    upperlimit = [False]*len(uvoir),
    date = uvoir.MJD.tolist(),
    date_format = "MJD",
    filter_key = uvoir["Filter"].tolist(),
    obs_type = "uvoir"
)

filts, idxs = np.unique(uvoir["Filter"], return_index=True)
print(filts)
filter_alias = [
    dict(
        filter_key = f,
        filter_name = f,
        wave_eff = otter.util.FILTER_MAP_WAVE[f],
        wave_units = "nm"
    ) for f in filts
]

# test the otter dataset format based on our schema
otter.schema.PhotometrySchema(**uvoir_phot);
for f in filter_alias:
    otter.schema.FilterSchema(**f);
# Out:
# ['b' 'u' 'uvm2' 'uvw1' 'uvw2' 'v']

# %% [markdown]
# ### Radio Dataset

# %%
radio = pd.read_csv("asassn15oi_radio.txt", sep=" ")
srcmap = {
    "this": [hajela24_bibcode],
    "VLASS": [hajela24_bibcode, "2020PASP..132c5001L"]
}

radio["iso"] = radio.Date.replace(month_map, regex=True)

radio_phot = [
    dict(
        reference = srcmap[src],
        raw = grp.Fν_mJy.tolist(),
        raw_err = grp.Fv_err.tolist(),
        raw_units = "mJy",
        corr_k = False,
        corr_s = False,
        corr_av = False,
        corr_host = False,
        corr_hostav = False,
        upperlimit = grp.upperlimit.tolist(),
        date = grp.iso,
        date_format = "iso",
        filter_key = (grp.ν_GHz.astype(str)+["GHz"]*len(grp)).tolist(),
        obs_type = "radio",
        telescope = tele
    ) for (tele, src), grp in radio.groupby(["Observatory", "Source"])
]

filter_alias += [
    dict(
        filter_key = str(f)+"GHz",
        filter_name = otter.util.freq_to_band(f*u.GHz),
        freq_eff = f,
        freq_units = "GHz"
    ) for f in radio.ν_GHz.unique()
]

# test the otter dataset format based on our schema
for r in radio_phot:
    otter.schema.PhotometrySchema(**r);
for f in filter_alias:
    otter.schema.FilterSchema(**f);
# Out:
# /home/nfranz/.local/lib/anaconda3/lib/python3.11/site-packages/pydantic/main.py:193: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   self.__pydantic_validator__.validate_python(data, self_instance=self)

# %% [markdown]
# ### X-ray dataset

# %%
xray = pd.read_csv(os.path.join(args.indir, "asassn15oi_xray.txt"), sep=" ")

band_map = {
    "swift" : "0.3 - 10",
    "XMM-Newton" : "0.2 - 12"
}

xray["model_name"] = [
    "Absorbed Powerlaw + Blackbody",
    "Absorbed Powerlaw + Blackbody",
    "Absorbed Powerlaw + Blackbody",
    "Absorbed Powerlaw + Blackbody",
    "Absorbed Powerlaw + Blackbody",
    "Absorbed Powerlaw",
    "Absorbed Powerlaw",
    "Powerlaw + Blackbody",
    "Absorbed Powerlaw + Blackbody",
    "Absorbed Powerlaw + Blackbody",
    "Powerlaw + Blackbody",
    "Absorbed Powerlaw + Blackbody",
    "Absorbed Powerlaw + Blackbody",
    "Absorbed Powerlaw + Blackbody",
    "Absorbed Powerlaw"
]

gPL = Param(name="gamma_PL", unit="None", description="Photon Index for Powerlaw model")
FPL = Param(name="F_PL", unit="10^-14 erg/cm^2/s", description="Unabsorbed flux for Powerlaw model")
kT = Param(name="kT_BB", unit="10^-2 keV", description="k*T for the Blackbody model")
FBB = Param(name="F_BB", unit="10^-13 erg/cm^2/s", description="Unabsorbed flux for Blackbody model")
RBB = Param(name="R_BB", unit="10^12 cm", description="Blackbody radius")
all_ = [gPL, FPL, kT, FBB, RBB]
xray["param_names"] = [
    all_,
    all_,
    all_,
    all_,
    [gPL,  FPL, kT, FBB],
    [gPL, FPL],
    [gPL, FPL],
    [gPL, kT, FBB, RBB],
    all_,
    all_,
    [gPL, kT, FBB, RBB],
    all_,
    all_,
    [gPL,  FPL, kT, FBB],
    [gPL, FPL]
]

for p in all_:
    xray[[p.name, p.name+"_lower", p.name+"_upper"]].astype(float)

def compute_flux(row):
    if not pd.isna(row.F_PL) and not pd.isna(row.F_BB) and not row.F_PL_upperlimit and not row.F_BB_upperlimit:
        return (
            row.F_PL*1e-14 + row.F_BB*1e-13, 
            (
                np.sqrt((row.F_PL_upper*1e-14)**2 + (row.F_BB_upper*1e-13)**2) + 
                np.sqrt((row.F_PL_lower*1e-14)**2 + (row.F_BB_lower*1e-13)**2)
            )/2,
            False,
            np.sqrt((row.F_PL_upper*1e-14)**2 + (row.F_BB_upper*1e-13)**2),
            np.sqrt((row.F_PL_lower*1e-14)**2 + (row.F_BB_lower*1e-13)**2)
        )
            
    elif (pd.isna(row.F_PL) or row.F_PL_upperlimit) and not pd.isna(row.F_BB) and not row.F_BB_upperlimit:
        return row.F_BB*1e-13, (row.F_BB_upper + abs(row.F_BB_lower))/2 * 1e-13, False, row.F_BB_upper, abs(row.F_BB_lower)
    
    elif (pd.isna(row.F_BB) or row.F_BB_upperlimit) and not pd.isna(row.F_PL) and not row.F_PL_upperlimit:
        return row.F_PL*1e-14, (row.F_PL_upper + abs(row.F_PL_lower))/2 * 1e-14, False, row.F_PL_upper, abs(row.F_PL_lower)
    
    elif row.F_PL_upperlimit:
        return row.F_PL*1e-14, 0, True, 0, 0
    
    else:
        print(row)
        raise ValueError()

xray["flux"], xray["flux_err"], xray["upperlimit"], xray["flux_upper"], xray["flux_lower"] = list(zip(*xray.apply(compute_flux, axis=1).tolist()))

print(xray)
        
N_H = 5.6e20 # cm^-2

xray_phot = [
    dict(
        reference = [hajela24_bibcode],
        raw = grp.flux.tolist(),
        raw_err = grp.flux_err.tolist(),
        raw_units = "erg/s/cm^2",
        corr_k = False,
        corr_s = False,
        corr_av = False,
        corr_host = False,
        corr_hostav = False,
        val_host = grp.F_abs*1e-14,
        upperlimit = grp.upperlimit,
        date = grp.dt + 57248.0,
        date_format = "MJD",
        filter_key = band_map[tele],
        obs_type = "xray",
        telescope = tele,
        raw_err_detail = dict(
            upper = xray.flux_upper.tolist(),
            lower = xray.flux_lower.tolist()
        ),
        xray_model = [
            dict(
                model_name = row.model_name,
                param_names = row.param_names,
                param_values = [row[name.name] for name in row.param_names],
                param_units = [p.unit for p in row.param_names],
                param_value_err_upper = [row[name.name+"_upper"] for name in row.param_names],
                param_value_err_lower = [row[name.name+"_lower"] for name in row.param_names],
                param_upperlimit = [row[name.name+"_upperlimit"] for name in row.param_names],
                param_descriptions = [p.description for p in row.param_names],
                model_reference = [hajela24_bibcode],
                min_energy = float(band_map[tele].split('-')[0].strip()),
                max_energy = float(band_map[tele].split()[-1].strip()),
                energy_units = "keV"
            ) for _, row in grp.iterrows()
        ]
    ) for (src, tele), grp in xray.groupby(["source", "telescope"])
]

# NEED TO DO FILTERS NEXT!!!
# Out:
#         dt  exposure_ks  gamma_PL  gamma_PL_upper  gamma_PL_lower  \
# 0     58.6         61.7       1.7             0.5            -0.5
# 1    252.1         31.0       2.0             0.0             0.0
# 2    329.0         11.7       2.0             0.0             0.0
# 3    425.1          6.1       2.0             0.0             0.0
# 4   1444.9         25.3       2.3             0.3            -0.3
# 5   2401.0          7.2       2.0             0.0             0.0
# 6   2580.0          7.0       2.0             0.0             0.0
# 7     76.4         10.3       2.5             0.8            -0.8
# 8     76.4         12.4       1.7             1.0            -0.8
# 9     76.4          9.7       1.5             0.5            -0.4
# 10   234.5         12.0       3.3             1.3            -1.3
# 11   234.5         14.0       4.8             2.6            -1.2
# 12   234.5         10.9       3.1             1.2            -0.9
# 13  1833.0         12.5       2.0             0.3            -0.3
# 14  2794.0         19.7       2.0             0.0             0.0
#
#     gamma_PL_upperlimit  F_PL  F_PL_upper  F_PL_lower F_PL_upperlimit  ...  \
# 0                 False   2.4         0.7        -0.7           False  ...
# 1                 False   3.6         0.0         0.0            True  ...
# 2                 False   4.1         2.1        -1.7           False  ...
# 3                 False   5.3         3.1        -2.4           False  ...
# 4                 False   8.5         1.4        -1.5           False  ...
# 5                 False  17.0         0.0         0.0            True  ...
# 6                 False   5.3         2.5        -2.5           False  ...
# 7                 False   NaN         NaN         NaN             NaN  ...
# 8                 False   2.3         0.8        -0.8           False  ...
# 9                 False   1.9         0.6        -0.6           False  ...
# 10                False   NaN         NaN         NaN             NaN  ...
# 11                False   1.5         0.8        -0.8           False  ...
# 12                False   0.9         0.7        -0.5           False  ...
# 13                False   1.0         0.4        -0.2           False  ...
# 14                False   0.8         0.0         0.0            True  ...
#
#     F_abs_upperlimit     source   telescope                     model_name  \
# 0              False       this       swift  Absorbed Powerlaw + Blackbody
# 1              False       this       swift  Absorbed Powerlaw + Blackbody
# 2              False       this       swift  Absorbed Powerlaw + Blackbody
# 3              False       this       swift  Absorbed Powerlaw + Blackbody
# 4                NaN       this       swift  Absorbed Powerlaw + Blackbody
# 5                NaN       this       swift              Absorbed Powerlaw
# 6                NaN       this       swift              Absorbed Powerlaw
# 7              False   Gezari17  XMM-Newton           Powerlaw + Blackbody
# 8                NaN  Holoien18  XMM-Newton  Absorbed Powerlaw + Blackbody
# 9              False       this  XMM-Newton  Absorbed Powerlaw + Blackbody
# 10             False   Gezari17  XMM-Newton           Powerlaw + Blackbody
# 11               NaN  Holoien18  XMM-Newton  Absorbed Powerlaw + Blackbody
# 12             False       this  XMM-Newton  Absorbed Powerlaw + Blackbody
# 13               NaN       this  XMM-Newton  Absorbed Powerlaw + Blackbody
# 14               NaN       this  XMM-Newton              Absorbed Powerlaw
#
#                                           param_names          flux  \
# 0   [Param(name='gamma_PL', unit='None', descripti...  1.540000e-13
# 1   [Param(name='gamma_PL', unit='None', descripti...  6.500000e-13
# 2   [Param(name='gamma_PL', unit='None', descripti...  9.310000e-13
# 3   [Param(name='gamma_PL', unit='None', descripti...  3.430000e-13
# 4   [Param(name='gamma_PL', unit='None', descripti...  8.500000e-14
# 5   [Param(name='gamma_PL', unit='None', descripti...  1.700000e-13
# 6   [Param(name='gamma_PL', unit='None', descripti...  5.300000e-14
# 7   [Param(name='gamma_PL', unit='None', descripti...  1.600000e-13
# 8   [Param(name='gamma_PL', unit='None', descripti...  1.430000e-13
# 9   [Param(name='gamma_PL', unit='None', descripti...  1.490000e-13
# 10  [Param(name='gamma_PL', unit='None', descripti...  1.800000e-12
# 11  [Param(name='gamma_PL', unit='None', descripti...  3.350000e-13
# 12  [Param(name='gamma_PL', unit='None', descripti...  8.990000e-13
# 13  [Param(name='gamma_PL', unit='None', descripti...  1.000000e-14
# 14  [Param(name='gamma_PL', unit='None', descripti...  8.000000e-15
#
#         flux_err upperlimit    flux_upper    flux_lower
# 0   2.118962e-14      False  2.118962e-14  2.118962e-14
# 1   6.500000e-14      False  7.000000e-01  6.000000e-01
# 2   1.116292e-13      False  1.218236e-13  1.014347e-13
# 3   8.459464e-14      False  9.518929e-14  7.400000e-14
# 4   1.450000e-14      False  1.400000e+00  1.500000e+00
# 5   0.000000e+00       True  0.000000e+00  0.000000e+00
# 6   2.500000e-14      False  2.500000e+00  2.500000e+00
# 7   0.000000e+00      False  0.000000e+00  0.000000e+00
# 8   5.063596e-14      False  5.063596e-14  5.063596e-14
# 9   1.166190e-14      False  1.166190e-14  1.166190e-14
# 10  0.000000e+00      False  0.000000e+00  0.000000e+00
# 11  9.533717e-14      False  9.035486e-14  1.003195e-13
# 12  2.090257e-14      False  2.118962e-14  2.061553e-14
# 13  3.000000e-15      False  4.000000e-01  2.000000e-01
# 14  0.000000e+00       True  0.000000e+00  0.000000e+00
#
# [15 rows x 35 columns]

# %%
xray_phot
# Out:
# [{'reference': ['2024arXiv240719019H'],
#   'raw': [1.6000000000000003e-13, 1.8e-12],
#   'raw_err': [0.0, 0.0],
#   'raw_units': 'erg/s/cm^2',
#   'corr_k': False,
#   'corr_s': False,
#   'corr_av': False,
#   'corr_host': False,
#   'corr_hostav': False,
#   'upperlimit': 7     False
#   10    False
#   Name: upperlimit, dtype: bool,
#   'date': 7     57324.4
#   10    57482.5
#   Name: dt, dtype: float64,
#   'date_format': 'MJD',
#   'filter_key': '0.2 - 12',
#   'obs_type': 'xray',
#   'telescope': 'XMM-Newton',
#   'raw_err_detail': {'upper': [2.1189620100417094e-14,
#     0.7,
#     1.218236430254817e-13,
#     9.518928511129812e-14,
#     1.4,
#     0.0,
#     2.5,
#     0.0,
#     5.063595560468865e-14,
#     1.1661903789690603e-14,
#     0.0,
#     9.035485598461215e-14,
#     2.1189620100417094e-14,
#     0.4,
#     0.0],
#    'lower': [2.1189620100417094e-14,
#     0.6,
#     1.0143470806385752e-13,
#     7.399999999999999e-14,
#     1.5,
#     0.0,
#     2.5,
#     0.0,
#     5.063595560468865e-14,
#     1.1661903789690603e-14,
#     0.0,
#     1.0031948963187562e-13,
#     2.0615528128088306e-14,
#     0.2,
#     0.0]},
#   'xray_model': [{'model_name': 'Powerlaw + Blackbody',
#     'param_names': [Param(name='gamma_PL', unit='None', description='Photon Index for Powerlaw model'),
#      Param(name='kT_BB', unit='10^-2 keV', description='k*T for the Blackbody model'),
#      Param(name='F_BB', unit='10^-13 erg/cm^2/s', description='Unabsorbed flux for Blackbody model'),
#      Param(name='R_BB', unit='10^12 cm', description='Blackbody radius')],
#     'param_values': [2.5, 4.7, 1.6, 0.4],
#     'param_units': ['None', '10^-2 keV', '10^-13 erg/cm^2/s', '10^12 cm'],
#     'param_value_err_upper': [0.8, 0.2, 0.0, 0.0],
#     'param_value_err_lower': [-0.8, -0.2, 0.0, 0.0],
#     'param_upperlimit': [False, False, False, False],
#     'param_descriptions': ['Photon Index for Powerlaw model',
#      'k*T for the Blackbody model',
#      'Unabsorbed flux for Blackbody model',
#      'Blackbody radius'],
#     'model_reference': ['2024arXiv240719019H'],
#     'min_energy': 0.2,
#     'max_energy': 12.0,
#     'energy_units': 'keV'},
#    {'model_name': 'Powerlaw + Blackbody',
#     'param_names': [Param(name='gamma_PL', unit='None', description='Photon Index for Powerlaw model'),
#      Param(name='kT_BB', unit='10^-2 keV', description='k*T for the Blackbody model'),
#      Param(name='F_BB', unit='10^-13 erg/cm^2/s', description='Unabsorbed flux for Blackbody model'),
#      Param(name='R_BB', unit='10^12 cm', description='Blackbody radius')],
#     'param_values': [3.3, 4.2, 18.0, 2.1],
#     'param_units': ['None', '10^-2 keV', '10^-13 erg/cm^2/s', '10^12 cm'],
#     'param_value_err_upper': [1.3, 0.1, 0.0, 0.0],
#     'param_value_err_lower': [-1.3, -0.1, 0.0, 0.0],
#     'param_upperlimit': [False, False, False, False],
#     'param_descriptions': ['Photon Index for Powerlaw model',
#      'k*T for the Blackbody model',
#      'Unabsorbed flux for Blackbody model',
#      'Blackbody radius'],
#     'model_reference': ['2024arXiv240719019H'],
#     'min_energy': 0.2,
#     'max_energy': 12.0,
#     'energy_units': 'keV'}]},
#  {'reference': ['2024arXiv240719019H'],
#   'raw': [1.43e-13, 3.3500000000000004e-13],
#   'raw_err': [5.063595560468865e-14, 9.533717280824389e-14],
#   'raw_units': 'erg/s/cm^2',
#   'corr_k': False,
#   'corr_s': False,
#   'corr_av': False,
#   'corr_host': False,
#   'corr_hostav': False,
#   'upperlimit': 8     False
#   11    False
#   Name: upperlimit, dtype: bool,
#   'date': 8     57324.4
#   11    57482.5
#   Name: dt, dtype: float64,
#   'date_format': 'MJD',
#   'filter_key': '0.2 - 12',
#   'obs_type': 'xray',
#   'telescope': 'XMM-Newton',
#   'raw_err_detail': {'upper': [2.1189620100417094e-14,
#     0.7,
#     1.218236430254817e-13,
#     9.518928511129812e-14,
#     1.4,
#     0.0,
#     2.5,
#     0.0,
#     5.063595560468865e-14,
#     1.1661903789690603e-14,
#     0.0,
#     9.035485598461215e-14,
#     2.1189620100417094e-14,
#     0.4,
#     0.0],
#    'lower': [2.1189620100417094e-14,
#     0.6,
#     1.0143470806385752e-13,
#     7.399999999999999e-14,
#     1.5,
#     0.0,
#     2.5,
#     0.0,
#     5.063595560468865e-14,
#     1.1661903789690603e-14,
#     0.0,
#     1.0031948963187562e-13,
#     2.0615528128088306e-14,
#     0.2,
#     0.0]},
#   'xray_model': [{'model_name': 'Absorbed Powerlaw + Blackbody',
#     'param_names': [Param(name='gamma_PL', unit='None', description='Photon Index for Powerlaw model'),
#      Param(name='F_PL', unit='10^-14 erg/cm^2/s', description='Unabsorbed flux for Powerlaw model'),
#      Param(name='kT_BB', unit='10^-2 keV', description='k*T for the Blackbody model'),
#      Param(name='F_BB', unit='10^-13 erg/cm^2/s', description='Unabsorbed flux for Blackbody model'),
#      Param(name='R_BB', unit='10^12 cm', description='Blackbody radius')],
#     'param_values': [1.7, 2.3, 6.2, 1.2, 0.5],
#     'param_units': ['None',
#      '10^-14 erg/cm^2/s',
#      '10^-2 keV',
#      '10^-13 erg/cm^2/s',
#      '10^12 cm'],
#     'param_value_err_upper': [1.0, 0.8, 6.0, 0.5, 0.6],
#     'param_value_err_lower': [-0.8, -0.8, -6.0, -0.5, -0.6],
#     'param_upperlimit': [False, False, False, False, False],
#     'param_descriptions': ['Photon Index for Powerlaw model',
#      'Unabsorbed flux for Powerlaw model',
#      'k*T for the Blackbody model',
#      'Unabsorbed flux for Blackbody model',
#      'Blackbody radius'],
#     'model_reference': ['2024arXiv240719019H'],
#     'min_energy': 0.2,
#     'max_energy': 12.0,
#     'energy_units': 'keV'},
#    {'model_name': 'Absorbed Powerlaw + Blackbody',
#     'param_names': [Param(name='gamma_PL', unit='None', description='Photon Index for Powerlaw model'),
#      Param(name='F_PL', unit='10^-14 erg/cm^2/s', description='Unabsorbed flux for Powerlaw model'),
#      Param(name='kT_BB', unit='10^-2 keV', description='k*T for the Blackbody model'),
#      Param(name='F_BB', unit='10^-13 erg/cm^2/s', description='Unabsorbed flux for Blackbody model'),
#      Param(name='R_BB', unit='10^12 cm', description='Blackbody radius')],
#     'param_values': [4.8, 1.5, 5.3, 3.2, 1.1],
#     'param_units': ['None',
#      '10^-14 erg/cm^2/s',
#      '10^-2 keV',
#      '10^-13 erg/cm^2/s',
#      '10^12 cm'],
#     'param_value_err_upper': [2.6, 0.8, 2.0, 0.9, 0.8],
#     'param_value_err_lower': [-1.2, -0.8, -2.0, -1.0, -0.8],
#     'param_upperlimit': [False, False, False, False, False],
#     'param_descriptions': ['Photon Index for Powerlaw model',
#      'Unabsorbed flux for Powerlaw model',
#      'k*T for the Blackbody model',
#      'Unabsorbed flux for Blackbody model',
#      'Blackbody radius'],
#     'model_reference': ['2024arXiv240719019H'],
#     'min_energy': 0.2,
#     'max_energy': 12.0,
#     'energy_units': 'keV'}]},
#  {'reference': ['2024arXiv240719019H'],
#   'raw': [1.49e-13, 8.99e-13, 1e-14, 8e-15],
#   'raw_err': [1.1661903789690603e-14,
#    2.0902574114252702e-14,
#    3.0000000000000006e-15,
#    0.0],
#   'raw_units': 'erg/s/cm^2',
#   'corr_k': False,
#   'corr_s': False,
#   'corr_av': False,
#   'corr_host': False,
#   'corr_hostav': False,
#   'upperlimit': 9     False
#   12    False
#   13    False
#   14     True
#   Name: upperlimit, dtype: bool,
#   'date': 9     57324.4
#   12    57482.5
#   13    59081.0
#   14    60042.0
#   Name: dt, dtype: float64,
#   'date_format': 'MJD',
#   'filter_key': '0.2 - 12',
#   'obs_type': 'xray',
#   'telescope': 'XMM-Newton',
#   'raw_err_detail': {'upper': [2.1189620100417094e-14,
#     0.7,
#     1.218236430254817e-13,
#     9.518928511129812e-14,
#     1.4,
#     0.0,
#     2.5,
#     0.0,
#     5.063595560468865e-14,
#     1.1661903789690603e-14,
#     0.0,
#     9.035485598461215e-14,
#     2.1189620100417094e-14,
#     0.4,
#     0.0],
#    'lower': [2.1189620100417094e-14,
#     0.6,
#     1.0143470806385752e-13,
#     7.399999999999999e-14,
#     1.5,
#     0.0,
#     2.5,
#     0.0,
#     5.063595560468865e-14,
#     1.1661903789690603e-14,
#     0.0,
#     1.0031948963187562e-13,
#     2.0615528128088306e-14,
#     0.2,
#     0.0]},
#   'xray_model': [{'model_name': 'Absorbed Powerlaw + Blackbody',
#     'param_names': [Param(name='gamma_PL', unit='None', description='Photon Index for Powerlaw model'),
#      Param(name='F_PL', unit='10^-14 erg/cm^2/s', description='Unabsorbed flux for Powerlaw model'),
#      Param(name='kT_BB', unit='10^-2 keV', description='k*T for the Blackbody model'),
#      Param(name='F_BB', unit='10^-13 erg/cm^2/s', description='Unabsorbed flux for Blackbody model'),
#      Param(name='R_BB', unit='10^12 cm', description='Blackbody radius')],
#     'param_values': [1.5, 1.9, 5.1, 1.3, 0.2],
#     'param_units': ['None',
#      '10^-14 erg/cm^2/s',
#      '10^-2 keV',
#      '10^-13 erg/cm^2/s',
#      '10^12 cm'],
#     'param_value_err_upper': [0.5, 0.6, 0.3, 0.1, 0.1],
#     'param_value_err_lower': [-0.4, -0.6, -0.3, -0.1, -0.1],
#     'param_upperlimit': [False, False, False, False, False],
#     'param_descriptions': ['Photon Index for Powerlaw model',
#      'Unabsorbed flux for Powerlaw model',
#      'k*T for the Blackbody model',
#      'Unabsorbed flux for Blackbody model',
#      'Blackbody radius'],
#     'model_reference': ['2024arXiv240719019H'],
#     'min_energy': 0.2,
#     'max_energy': 12.0,
#     'energy_units': 'keV'},
#    {'model_name': 'Absorbed Powerlaw + Blackbody',
#     'param_names': [Param(name='gamma_PL', unit='None', description='Photon Index for Powerlaw model'),
#      Param(name='F_PL', unit='10^-14 erg/cm^2/s', description='Unabsorbed flux for Powerlaw model'),
#      Param(name='kT_BB', unit='10^-2 keV', description='k*T for the Blackbody model'),
#      Param(name='F_BB', unit='10^-13 erg/cm^2/s', description='Unabsorbed flux for Blackbody model'),
#      Param(name='R_BB', unit='10^12 cm', description='Blackbody radius')],
#     'param_values': [3.1, 0.9, 4.2, 8.9, 1.3],
#     'param_units': ['None',
#      '10^-14 erg/cm^2/s',
#      '10^-2 keV',
#      '10^-13 erg/cm^2/s',
#      '10^12 cm'],
#     'param_value_err_upper': [1.2, 0.7, 0.1, 0.2, 0.1],
#     'param_value_err_lower': [-0.9, -0.5, -0.1, -0.2, -0.1],
#     'param_upperlimit': [False, False, False, False, False],
#     'param_descriptions': ['Photon Index for Powerlaw model',
#      'Unabsorbed flux for Powerlaw model',
#      'k*T for the Blackbody model',
#      'Unabsorbed flux for Blackbody model',
#      'Blackbody radius'],
#     'model_reference': ['2024arXiv240719019H'],
#     'min_energy': 0.2,
#     'max_energy': 12.0,
#     'energy_units': 'keV'},
#    {'model_name': 'Absorbed Powerlaw + Blackbody',
#     'param_names': [Param(name='gamma_PL', unit='None', description='Photon Index for Powerlaw model'),
#      Param(name='F_PL', unit='10^-14 erg/cm^2/s', description='Unabsorbed flux for Powerlaw model'),
#      Param(name='kT_BB', unit='10^-2 keV', description='k*T for the Blackbody model'),
#      Param(name='F_BB', unit='10^-13 erg/cm^2/s', description='Unabsorbed flux for Blackbody model')],
#     'param_values': [2.0, 1.0, 5.2, 0.042],
#     'param_units': ['None',
#      '10^-14 erg/cm^2/s',
#      '10^-2 keV',
#      '10^-13 erg/cm^2/s'],
#     'param_value_err_upper': [0.3, 0.4, 0.0, 0.0],
#     'param_value_err_lower': [-0.3, -0.2, 0.0, 0.0],
#     'param_upperlimit': [False, False, False, True],
#     'param_descriptions': ['Photon Index for Powerlaw model',
#      'Unabsorbed flux for Powerlaw model',
#      'k*T for the Blackbody model',
#      'Unabsorbed flux for Blackbody model'],
#     'model_reference': ['2024arXiv240719019H'],
#     'min_energy': 0.2,
#     'max_energy': 12.0,
#     'energy_units': 'keV'},
#    {'model_name': 'Absorbed Powerlaw',
#     'param_names': [Param(name='gamma_PL', unit='None', description='Photon Index for Powerlaw model'),
#      Param(name='F_PL', unit='10^-14 erg/cm^2/s', description='Unabsorbed flux for Powerlaw model')],
#     'param_values': [2.0, 0.8],
#     'param_units': ['None', '10^-14 erg/cm^2/s'],
#     'param_value_err_upper': [0.0, 0.0],
#     'param_value_err_lower': [0.0, 0.0],
#     'param_upperlimit': [False, True],
#     'param_descriptions': ['Photon Index for Powerlaw model',
#      'Unabsorbed flux for Powerlaw model'],
#     'model_reference': ['2024arXiv240719019H'],
#     'min_energy': 0.2,
#     'max_energy': 12.0,
#     'energy_units': 'keV'}]},
#  {'reference': ['2024arXiv240719019H'],
#   'raw': [1.54e-13,
#    6.500000000000001e-13,
#    9.31e-13,
#    3.4299999999999995e-13,
#    8.5e-14,
#    1.7e-13,
#    5.2999999999999995e-14],
#   'raw_err': [2.1189620100417094e-14,
#    6.499999999999999e-14,
#    1.1162917554466961e-13,
#    8.459464255564905e-14,
#    1.4499999999999998e-14,
#    0.0,
#    2.5e-14],
#   'raw_units': 'erg/s/cm^2',
#   'corr_k': False,
#   'corr_s': False,
#   'corr_av': False,
#   'corr_host': False,
#   'corr_hostav': False,
#   'upperlimit': 0    False
#   1    False
#   2    False
#   3    False
#   4    False
#   5     True
#   6    False
#   Name: upperlimit, dtype: bool,
#   'date': 0    57306.6
#   1    57500.1
#   2    57577.0
#   3    57673.1
#   4    58692.9
#   5    59649.0
#   6    59828.0
#   Name: dt, dtype: float64,
#   'date_format': 'MJD',
#   'filter_key': '0.3 - 10',
#   'obs_type': 'xray',
#   'telescope': 'swift',
#   'raw_err_detail': {'upper': [2.1189620100417094e-14,
#     0.7,
#     1.218236430254817e-13,
#     9.518928511129812e-14,
#     1.4,
#     0.0,
#     2.5,
#     0.0,
#     5.063595560468865e-14,
#     1.1661903789690603e-14,
#     0.0,
#     9.035485598461215e-14,
#     2.1189620100417094e-14,
#     0.4,
#     0.0],
#    'lower': [2.1189620100417094e-14,
#     0.6,
#     1.0143470806385752e-13,
#     7.399999999999999e-14,
#     1.5,
#     0.0,
#     2.5,
#     0.0,
#     5.063595560468865e-14,
#     1.1661903789690603e-14,
#     0.0,
#     1.0031948963187562e-13,
#     2.0615528128088306e-14,
#     0.2,
#     0.0]},
#   'xray_model': [{'model_name': 'Absorbed Powerlaw + Blackbody',
#     'param_names': [Param(name='gamma_PL', unit='None', description='Photon Index for Powerlaw model'),
#      Param(name='F_PL', unit='10^-14 erg/cm^2/s', description='Unabsorbed flux for Powerlaw model'),
#      Param(name='kT_BB', unit='10^-2 keV', description='k*T for the Blackbody model'),
#      Param(name='F_BB', unit='10^-13 erg/cm^2/s', description='Unabsorbed flux for Blackbody model'),
#      Param(name='R_BB', unit='10^12 cm', description='Blackbody radius')],
#     'param_values': [1.7, 2.4, 4.5, 1.3, 0.4],
#     'param_units': ['None',
#      '10^-14 erg/cm^2/s',
#      '10^-2 keV',
#      '10^-13 erg/cm^2/s',
#      '10^12 cm'],
#     'param_value_err_upper': [0.5, 0.7, 0.5, 0.2, 0.4],
#     'param_value_err_lower': [-0.5, -0.7, -0.6, -0.2, -0.1],
#     'param_upperlimit': [False, False, False, False, False],
#     'param_descriptions': ['Photon Index for Powerlaw model',
#      'Unabsorbed flux for Powerlaw model',
#      'k*T for the Blackbody model',
#      'Unabsorbed flux for Blackbody model',
#      'Blackbody radius'],
#     'model_reference': ['2024arXiv240719019H'],
#     'min_energy': 0.3,
#     'max_energy': 10.0,
#     'energy_units': 'keV'},
#    {'model_name': 'Absorbed Powerlaw + Blackbody',
#     'param_names': [Param(name='gamma_PL', unit='None', description='Photon Index for Powerlaw model'),
#      Param(name='F_PL', unit='10^-14 erg/cm^2/s', description='Unabsorbed flux for Powerlaw model'),
#      Param(name='kT_BB', unit='10^-2 keV', description='k*T for the Blackbody model'),
#      Param(name='F_BB', unit='10^-13 erg/cm^2/s', description='Unabsorbed flux for Blackbody model'),
#      Param(name='R_BB', unit='10^12 cm', description='Blackbody radius')],
#     'param_values': [2.0, 3.6, 4.9, 6.5, 0.6],
#     'param_units': ['None',
#      '10^-14 erg/cm^2/s',
#      '10^-2 keV',
#      '10^-13 erg/cm^2/s',
#      '10^12 cm'],
#     'param_value_err_upper': [0.0, 0.0, 0.3, 0.7, 0.2],
#     'param_value_err_lower': [0.0, 0.0, -0.3, -0.6, -0.1],
#     'param_upperlimit': [False, True, False, False, False],
#     'param_descriptions': ['Photon Index for Powerlaw model',
#      'Unabsorbed flux for Powerlaw model',
#      'k*T for the Blackbody model',
#      'Unabsorbed flux for Blackbody model',
#      'Blackbody radius'],
#     'model_reference': ['2024arXiv240719019H'],
#     'min_energy': 0.3,
#     'max_energy': 10.0,
#     'energy_units': 'keV'},
#    {'model_name': 'Absorbed Powerlaw + Blackbody',
#     'param_names': [Param(name='gamma_PL', unit='None', description='Photon Index for Powerlaw model'),
#      Param(name='F_PL', unit='10^-14 erg/cm^2/s', description='Unabsorbed flux for Powerlaw model'),
#      Param(name='kT_BB', unit='10^-2 keV', description='k*T for the Blackbody model'),
#      Param(name='F_BB', unit='10^-13 erg/cm^2/s', description='Unabsorbed flux for Blackbody model'),
#      Param(name='R_BB', unit='10^12 cm', description='Blackbody radius')],
#     'param_values': [2.0, 4.1, 5.2, 8.9, 0.6],
#     'param_units': ['None',
#      '10^-14 erg/cm^2/s',
#      '10^-2 keV',
#      '10^-13 erg/cm^2/s',
#      '10^12 cm'],
#     'param_value_err_upper': [0.0, 2.1, 0.4, 1.2, 0.2],
#     'param_value_err_lower': [0.0, -1.7, -0.4, -1.0, -0.2],
#     'param_upperlimit': [False, False, False, False, False],
#     'param_descriptions': ['Photon Index for Powerlaw model',
#      'Unabsorbed flux for Powerlaw model',
#      'k*T for the Blackbody model',
#      'Unabsorbed flux for Blackbody model',
#      'Blackbody radius'],
#     'model_reference': ['2024arXiv240719019H'],
#     'min_energy': 0.3,
#     'max_energy': 10.0,
#     'energy_units': 'keV'},
#    {'model_name': 'Absorbed Powerlaw + Blackbody',
#     'param_names': [Param(name='gamma_PL', unit='None', description='Photon Index for Powerlaw model'),
#      Param(name='F_PL', unit='10^-14 erg/cm^2/s', description='Unabsorbed flux for Powerlaw model'),
#      Param(name='kT_BB', unit='10^-2 keV', description='k*T for the Blackbody model'),
#      Param(name='F_BB', unit='10^-13 erg/cm^2/s', description='Unabsorbed flux for Blackbody model'),
#      Param(name='R_BB', unit='10^12 cm', description='Blackbody radius')],
#     'param_values': [2.0, 5.3, 5.2, 2.9, 0.3],
#     'param_units': ['None',
#      '10^-14 erg/cm^2/s',
#      '10^-2 keV',
#      '10^-13 erg/cm^2/s',
#      '10^12 cm'],
#     'param_value_err_upper': [0.0, 3.1, 0.4, 0.9, 0.1],
#     'param_value_err_lower': [0.0, -2.4, -0.4, -0.7, -0.1],
#     'param_upperlimit': [False, False, False, False, False],
#     'param_descriptions': ['Photon Index for Powerlaw model',
#      'Unabsorbed flux for Powerlaw model',
#      'k*T for the Blackbody model',
#      'Unabsorbed flux for Blackbody model',
#      'Blackbody radius'],
#     'model_reference': ['2024arXiv240719019H'],
#     'min_energy': 0.3,
#     'max_energy': 10.0,
#     'energy_units': 'keV'},
#    {'model_name': 'Absorbed Powerlaw + Blackbody',
#     'param_names': [Param(name='gamma_PL', unit='None', description='Photon Index for Powerlaw model'),
#      Param(name='F_PL', unit='10^-14 erg/cm^2/s', description='Unabsorbed flux for Powerlaw model'),
#      Param(name='kT_BB', unit='10^-2 keV', description='k*T for the Blackbody model'),
#      Param(name='F_BB', unit='10^-13 erg/cm^2/s', description='Unabsorbed flux for Blackbody model')],
#     'param_values': [2.3, 8.5, 5.2, 0.6],
#     'param_units': ['None',
#      '10^-14 erg/cm^2/s',
#      '10^-2 keV',
#      '10^-13 erg/cm^2/s'],
#     'param_value_err_upper': [0.3, 1.4, 0.0, 0.0],
#     'param_value_err_lower': [-0.3, -1.5, 0.0, 0.0],
#     'param_upperlimit': [False, False, False, True],
#     'param_descriptions': ['Photon Index for Powerlaw model',
#      'Unabsorbed flux for Powerlaw model',
#      'k*T for the Blackbody model',
#      'Unabsorbed flux for Blackbody model'],
#     'model_reference': ['2024arXiv240719019H'],
#     'min_energy': 0.3,
#     'max_energy': 10.0,
#     'energy_units': 'keV'},
#    {'model_name': 'Absorbed Powerlaw',
#     'param_names': [Param(name='gamma_PL', unit='None', description='Photon Index for Powerlaw model'),
#      Param(name='F_PL', unit='10^-14 erg/cm^2/s', description='Unabsorbed flux for Powerlaw model')],
#     'param_values': [2.0, 17.0],
#     'param_units': ['None', '10^-14 erg/cm^2/s'],
#     'param_value_err_upper': [0.0, 0.0],
#     'param_value_err_lower': [0.0, 0.0],
#     'param_upperlimit': [False, True],
#     'param_descriptions': ['Photon Index for Powerlaw model',
#      'Unabsorbed flux for Powerlaw model'],
#     'model_reference': ['2024arXiv240719019H'],
#     'min_energy': 0.3,
#     'max_energy': 10.0,
#     'energy_units': 'keV'},
#    {'model_name': 'Absorbed Powerlaw',
#     'param_names': [Param(name='gamma_PL', unit='None', description='Photon Index for Powerlaw model'),
#      Param(name='F_PL', unit='10^-14 erg/cm^2/s', description='Unabsorbed flux for Powerlaw model')],
#     'param_values': [2.0, 5.3],
#     'param_units': ['None', '10^-14 erg/cm^2/s'],
#     'param_value_err_upper': [0.0, 2.5],
#     'param_value_err_lower': [0.0, -2.5],
#     'param_upperlimit': [False, False],
#     'param_descriptions': ['Photon Index for Powerlaw model',
#      'Unabsorbed flux for Powerlaw model'],
#     'model_reference': ['2024arXiv240719019H'],
#     'min_energy': 0.3,
#     'max_energy': 10.0,
#     'energy_units': 'keV'}]}]
